# %%
#https://tat-pytone.hatenablog.com/entry/2020/02/10/213332
#2in9display (296*128に最適)

from PIL import Image, ImageDraw, ImageFont
import textwrap
import cv2

# 表示させる文章
text = '昨日は雨が降りましたが、今日はとても良い天気でした。明日もきっと良い天気です。' 

im = Image.open('edp2in9disp.png')
draw = ImageDraw.Draw(im)  # drawオブジェクトを生成

wrap_list = textwrap.wrap(text, 10)  # テキストをn文字で改行しリストwrap_listに代入
font = ImageFont.truetype('C:\Windows\Fonts\meiryo.ttc', 28)  # フォントの指定
line_counter = 0  # 行数のカウンター
for line in wrap_list:  # wrap_listから1行づつ取り出しlineに代入
    y = line_counter*30  # y座標をline_counterに応じて下げる
    draw.multiline_text((5, y),line, fill=(0,0,0), font=font)  # 1行分の文字列を画像に描画
    line_counter = line_counter +1  # 行数のカウンターに1

im=im.rotate(90, expand=True)
im.save('output.png', quality=95)
im2 = cv2.imread("output.png", 0)
ret2, im2 = cv2.threshold(im2, 0, 255, cv2.THRESH_OTSU)
cv2.imwrite('output2.png',im2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3701/4099534627.py in <module>
#       4 from PIL import Image, ImageDraw, ImageFont
#       5 import textwrap
# ----> 6 import cv2
#       7
#       8 # 表示させる文章
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import numpy as np
im_gray = np.array(Image.open('output.png').convert('L'))
np.savetxt('image.csv', im_gray,delimiter=',', fmt='%d')
np.savetxt('image.dat', im_gray.flatten(),delimiter=',', fmt='%d')

# %%
im_nichi=np.array(Image.open('output.png').convert('L'))
im_nichi=im_nichi//255
im_senddata=[]
for i in range(296):
    for j in range(16):
        nishin=0
        for k in range(8):
            nishin+=im_nichi[i][j*8+k]
            if k!=7:
                nishin*=2
        im_senddata.append(nishin)
print(im_senddata)
# Out:
# [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 227, 255, 255, 248, 127, 255, 255, 255, 255, 255, 255, 255, 255, 255, 254, 63, 227, 255, 255, 0, 127, 255, 243, 255, 255, 255, 255, 255, 255, 255, 254, 63, 227, 255, 252, 0, 127, 254, 115, 255, 255, 255, 255, 255, 255, 255, 254, 63, 227, 255, 240, 0, 127, 254, 115, 255, 255, 255, 255, 255, 255, 255, 254, 63, 227, 255, 192, 63, 255, 254, 115, 198, 63, 255, 255, 255, 255, 255, 254, 63, 227, 255, 129, 255, 255, 254, 115, 134, 31, 255, 255, 255, 255, 255, 254, 63, 227, 255, 131, 255, 255, 254, 114, 7, 31, 255, 255, 255, 255, 255, 230, 63, 227, 255, 143, 255, 255, 254, 112, 7, 31, 255, 255, 255, 255, 255, 230, 63, 227, 255, 223, 255, 255, 254, 96, 15, 31, 255, 255, 255, 255, 255, 230, 63, 227, 255, 255, 255,